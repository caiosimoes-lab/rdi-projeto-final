# %% [markdown]
# # Análise – State of Data Brazil + Mercado de Trabalho

# %% [markdown]
# Este notebook documenta a análise exploratória, a preparação dos dados e os testes dos modelos de Recuperação da Informação (BM25, modelo vetorial etc.).

# %%
import pandas as pd
from pathlib import Path

base_file = Path("../data/processed/base_integrada.csv")
if base_file.exists():
    df = pd.read_csv(base_file)
    display(df.head())
    print("Linhas:", len(df))
else:
    print("Base integrada não encontrada. Rode primeiro os scripts de limpeza e integração.")
